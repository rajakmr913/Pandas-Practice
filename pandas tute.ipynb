# %% [markdown]
# ***pandas code***

# %%
import pandas as pd

# %%
import numpy as np

# %%
dict = {'name':['raja','king', 'royal', 'badsah','bahubali']
        , 'role':['student', 'kingdom manager' , 'rolex babu', 'singer rapper', 'actor']
        , 'performance':['90%','50%','45%','89%','99%']
       }

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#        name             role performance
# 0      raja          student         90%
# 1      king  kingdom manager         50%
# 2     royal       rolex babu         45%
# 3    badsah    singer rapper         89%
# 4  bahubali            actor         99%

# %%
df.to_csv('name.csv')

# %%
df.head(2)
# Out:
#    name             role performance
# 0  raja          student         90%
# 1  king  kingdom manager         50%

# %%
df.tail(3)
# Out:
#        name           role performance
# 2     royal     rolex babu         45%
# 3    badsah  singer rapper         89%
# 4  bahubali          actor         99%

# %%
df.describe()
# Out:
#         name     role performance
# count      5        5           5
# unique     5        5           5
# top     raja  student         90%
# freq       1        1           1

# %%
dict2 = {'roll no.':['5','7', '9']
        , 'marks':['50','70','90']
     
       }

# %%
df = pd.DataFrame(dict2)

# %%
df
# Out:
#   roll no. marks
# 0        5    50
# 1        7    70
# 2        9    90

# %%
df.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of   roll no. marks
# 0        5    50
# 1        7    70
# 2        9    90>

# %%
df.corr
# Out:
# <bound method DataFrame.corr of   roll no. marks
# 0        5    50
# 1        7    70
# 2        9    90>

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of   roll no. marks
# 0        5    50
# 1        7    70
# 2        9    90>

# %%
pd.__version__
# Out:
# '1.3.1'

# %%
list_pd =[1,2,-3,3.2,'raja']
print(list_pd)
# Out:
# [1, 2, -3, 3.2, 'raja']

# %%
series1=pd.Series(list_pd)
print(series1)
# Out:
# 0       1
# 1       2
# 2      -3
# 3     3.2
# 4    raja
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2 =pd.Series([1,2,3,6])
print(series2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    6
# dtype: int64

# %%
series3 = pd.Series([1,2,3,4] ,index=['a','b','c','d'])
print(series3)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
series3 = pd.Series([1,2,3,4] ,index=['a','b','c','d'], dtype = float)
print(series3)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
scaler_s = pd.Series(0.5)
print(scaler_s)
# Out:
# 0    0.5
# dtype: float64

# %%
scaler_s = pd.Series(0.5 , index=[1,2,3,4,5,6,7,8,9])
print(scaler_s)
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# 4    0.5
# 5    0.5
# 6    0.5
# 7    0.5
# 8    0.5
# 9    0.5
# dtype: float64

# %%
series2[1]
# Out:
# 2

# %%
series2[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
max(series2)
# Out:
# 6

# %%
min(series2)
# Out:
# 1

# %%
series2[series2>3]
# Out:
# 3    6
# dtype: int64

# %%
lst = ['a','s','d','f']
print(lst)
# Out:
# ['a', 's', 'd', 'f']

# %%
ddf1 =pd.DataFrame(lst)
print(ddf1)
# Out:
#    0
# 0  a
# 1  s
# 2  d
# 3  f

# %%
ddf1
# Out:
#    0
# 0  a
# 1  s
# 2  d
# 3  f

# %%
lstt =[[1,2,3],[2,4,5],[5,9,8]]

# %%
lstt
# Out:
# [[1, 2, 3], [2, 4, 5], [5, 9, 8]]

# %%
ddf2 =pd.DataFrame(lstt)

# %%
ddf2
# Out:
#    0  1  2
# 0  1  2  3
# 1  2  4  5
# 2  5  9  8

# %%
 df1 =pd.read_csv('name.csv')

# %%
import os

# %%
print(os.getcwd())
# Out:
# D:\all\python codes\numpy and pandas

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['roll no.', 'marks'], dtype='object')

# %%
 df1 =pd.read_csv('name.csv' ,nrows=1)

# %%
df1
# Out:
#    Unnamed: 0  name     role performance
# 0           0  raja  student         90%

# %%
 df1 =pd.read_csv('name.csv' ,usecols=[0,1])

# %%
df1
# Out:
#    Unnamed: 0      name
# 0           0      raja
# 1           1      king
# 2           2     royal
# 3           3    badsah
# 4           4  bahubali

# %%
 df2 =pd.read_csv('name.csv' ,skiprows=2)

# %%
df2
# Out:
#    1      king kingdom manager  50%
# 0  2     royal      rolex babu  45%
# 1  3    badsah   singer rapper  89%
# 2  4  bahubali           actor  99%

# %%
 df1
# Out:
#    Unnamed: 0      name             role performance
# 0           0      raja          student         90%
# 1           1      king  kingdom manager         50%
# 2           2     royal       rolex babu         45%
# 3           3    badsah    singer rapper         89%
# 4           4  bahubali            actor         99%

# %%
 df1 =pd.read_csv('name.csv' ,header =None)

# %%
df1
# Out:
#      0         1                2            3
# 0  NaN      name             role  performance
# 1  0.0      raja          student          90%
# 2  1.0      king  kingdom manager          50%
# 3  2.0     royal       rolex babu          45%
# 4  3.0    badsah    singer rapper          89%
# 5  4.0  bahubali            actor          99%

# %%
 df1 =pd.read_csv('name.csv' )

# %%
df1
# Out:
#    Unnamed: 0      name             role performance
# 0           0      raja          student         90%
# 1           1      king  kingdom manager         50%
# 2           2     royal       rolex babu         45%
# 3           3    badsah    singer rapper         89%
# 4           4  bahubali            actor         99%

# %%
df1 =pd.read_csv('name.csv' ,header =None ,prefix = "Data")

# %%
df1
# Out:
#    Data0     Data1            Data2        Data3
# 0    NaN      name             role  performance
# 1    0.0      raja          student          90%
# 2    1.0      king  kingdom manager          50%
# 3    2.0     royal       rolex babu          45%
# 4    3.0    badsah    singer rapper          89%
# 5    4.0  bahubali            actor          99%

# %%
df1 =pd.read_csv('name.csv' ,names = ["id", "gg","jj","bb"])

# %%
df1
# Out:
#     id        gg               jj           bb
# 0  NaN      name             role  performance
# 1  0.0      raja          student          90%
# 2  1.0      king  kingdom manager          50%
# 3  2.0     royal       rolex babu          45%
# 4  3.0    badsah    singer rapper          89%
# 5  4.0  bahubali            actor          99%

# %%
 df1 =pd.read_csv('name.csv')

# %%
df1.replace("raja" , "samreen")
# Out:
#    Unnamed: 0      name             role performance
# 0           0   samreen          student         90%
# 1           1      king  kingdom manager         50%
# 2           2     royal       rolex babu         45%
# 3           3    badsah    singer rapper         89%
# 4           4  bahubali            actor         99%

# %%
stock = pd.read_csv("D:\\all\\python codes\\projects\\stock price\\Final-50-stocks.csv")

# %%
stock.head()
# Out:
#          DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO   TECHM  RELIANCE  \
# 0  2010-01-11     591.90  423.70  3792.50    6737.95  735.60   1093.20
# 1  2010-01-12     613.55  414.70  3781.90    5443.70  671.15    988.80
# 2  2010-02-11     599.05  433.85  3818.70    6735.25  724.55   1074.85
# 3  2010-02-12     622.75  426.05  3784.20    5368.40  676.35   1011.15
# 4  2010-03-11     609.60  434.70  3833.05    6858.65  732.50   1065.30
#
#    SHREECEM  SUNPHARMA  TATAMOTORS  ...    BPCL  BRITANNIA  ADANIPORTS  \
# 0   2116.10    2190.70     1170.60  ...  754.80     413.15         NaN
# 1   2094.10     448.65     1286.75  ...  697.95     410.30         NaN
# 2   2164.55    2190.45     1154.25  ...  772.75     413.60         NaN
# 3   2022.35     452.90     1320.15  ...  685.80     412.45         NaN
# 4   2261.40    2249.30     1185.55  ...  765.60     415.75         NaN
#
#    BAJAJFINSERV  BAJAJFINANCE  BHARTIARTL  AXISBANK  BAJAJ-AUTO  ASIANPAINT  \
# ...

# %%
stock.isnull()
# Out:
#        DATE  TATASTEEL  WIPRO  TITAN  ULTRACEMO  TECHM  RELIANCE  SHREECEM  \
# 0     False      False  False  False      False  False     False     False
# 1     False      False  False  False      False  False     False     False
# 2     False      False  False  False      False  False     False     False
# 3     False      False  False  False      False  False     False     False
# 4     False      False  False  False      False  False     False     False
# ...     ...        ...    ...    ...        ...    ...       ...       ...
# 2706  False      False  False  False      False  False     False     False
# 2707  False      False  False  False      False  False     False     False
# 2708  False      False  False  False      False  False     False     False
# 2709  False      False  False  False      False  False     False     False
# 2710  False      False  False  False      False  False     False     False
#
# ...

# %%
stock.isnull().sum()
# Out:
# DATE               0
# TATASTEEL          0
# WIPRO              0
# TITAN              0
# ULTRACEMO          0
# TECHM              0
# RELIANCE           0
# SHREECEM           0
# SUNPHARMA          0
# TATAMOTORS         0
# TCS                0
# SBIN               0
# NESTLEIND          0
# NTPC               0
# M&M                0
# MARUTI             0
# ONGC               0
# POWERGRID          0
# JSWSTEEL           0
# KOTAKBANK          0
# LT                 0
# ICICIBANK          0
# INDUSBANK          0
# INFY             174
# IOC                0
# ITC                0
# HEROMOTOCO       202
# HINDALCO           0
# HINDUNILVR         0
# HCLTECH            0
# HDFCBANK           0
# HDFC               0
# DRREDDYS           0
# EICHERMOTOR        0
# GRASIM             0
# CIPLA              0
# COALINDIA         12
# BPCL               0
# BRITANNIA          0
# ADANIPORTS      1460
# BAJAJFINSERV       0
# BAJAJFINANCE       0
# BHARTIARTL         0
# ...

# %%
stock.interpolate()
# Out:
#             DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO    TECHM  RELIANCE  \
# 0     2010-01-11     591.90  423.70  3792.50    6737.95   735.60   1093.20
# 1     2010-01-12     613.55  414.70  3781.90    5443.70   671.15    988.80
# 2     2010-02-11     599.05  433.85  3818.70    6735.25   724.55   1074.85
# 3     2010-02-12     622.75  426.05  3784.20    5368.40   676.35   1011.15
# 4     2010-03-11     609.60  434.70  3833.05    6858.65   732.50   1065.30
# ...          ...        ...     ...      ...        ...      ...       ...
# 2706  2021-10-05    1216.35  525.95  1455.15    6403.10   990.50   1926.20
# 2707  2021-10-06    1114.45  554.25  1738.65    6709.65  1064.90   2183.00
# 2708  2021-10-08    1373.60  603.85  1799.20    7474.15  1323.05   2088.05
# 2709  2021-10-13    1354.30  672.60  2537.20    7350.40  1402.15   2694.95
# 2710  2021-10-14    1375.05  708.25  2564.05    7395.50  1430.80   2700.40
#
# ...

# %%
stock.index
# Out:
# RangeIndex(start=0, stop=2711, step=1)

# %%
stock.columns
# Out:
# Index(['DATE', 'TATASTEEL', 'WIPRO', 'TITAN', 'ULTRACEMO', 'TECHM', 'RELIANCE',
#        'SHREECEM', 'SUNPHARMA', 'TATAMOTORS', 'TCS', 'SBIN', 'NESTLEIND',
#        'NTPC', 'M&M', 'MARUTI', 'ONGC', 'POWERGRID', 'JSWSTEEL', 'KOTAKBANK',
#        'LT', 'ICICIBANK', 'INDUSBANK', 'INFY', 'IOC', 'ITC', 'HEROMOTOCO',
#        'HINDALCO', 'HINDUNILVR', 'HCLTECH', 'HDFCBANK', 'HDFC', 'DRREDDYS',
#        'EICHERMOTOR', 'GRASIM', 'CIPLA', 'COALINDIA', 'BPCL', 'BRITANNIA',
#        'ADANIPORTS', 'BAJAJFINSERV', 'BAJAJFINANCE', 'BHARTIARTL', 'AXISBANK',
#        'BAJAJ-AUTO', 'ASIANPAINT', 'UPL'],
#       dtype='object')

# %%
stock.tail()
# Out:
#             DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO    TECHM  RELIANCE  \
# 2706  2021-10-05    1216.35  525.95  1455.15    6403.10   990.50   1926.20
# 2707  2021-10-06    1114.45  554.25  1738.65    6709.65  1064.90   2183.00
# 2708  2021-10-08    1373.60  603.85  1799.20    7474.15  1323.05   2088.05
# 2709  2021-10-13    1354.30  672.60  2537.20    7350.40  1402.15   2694.95
# 2710  2021-10-14    1375.05  708.25  2564.05    7395.50  1430.80   2700.40
#
#       SHREECEM  SUNPHARMA  TATAMOTORS  ...    BPCL  BRITANNIA  ADANIPORTS  \
# 2706  27309.95     698.20      314.85  ...  453.70    3413.80      765.45
# 2707  28225.80     676.05      344.75  ...  483.55    3576.30      846.75
# 2708  27117.65     793.35      294.20  ...  444.70    3637.20      693.00
# 2709  27815.70     842.55      506.90  ...  458.65    3883.70      759.00
# 2710  27956.45     841.30      497.60  ...  459.30    3894.85      812.80
#
#       BAJAJFINSERV  BAJAJFINANCE  BHARTIARTL  AXISBANK  BAJAJ-AUTO  \
# ...

# %%
stock.interpolate(method = "linear")
# Out:
#             DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO    TECHM  RELIANCE  \
# 0     2010-01-11     591.90  423.70  3792.50    6737.95   735.60   1093.20
# 1     2010-01-12     613.55  414.70  3781.90    5443.70   671.15    988.80
# 2     2010-02-11     599.05  433.85  3818.70    6735.25   724.55   1074.85
# 3     2010-02-12     622.75  426.05  3784.20    5368.40   676.35   1011.15
# 4     2010-03-11     609.60  434.70  3833.05    6858.65   732.50   1065.30
# ...          ...        ...     ...      ...        ...      ...       ...
# 2706  2021-10-05    1216.35  525.95  1455.15    6403.10   990.50   1926.20
# 2707  2021-10-06    1114.45  554.25  1738.65    6709.65  1064.90   2183.00
# 2708  2021-10-08    1373.60  603.85  1799.20    7474.15  1323.05   2088.05
# 2709  2021-10-13    1354.30  672.60  2537.20    7350.40  1402.15   2694.95
# 2710  2021-10-14    1375.05  708.25  2564.05    7395.50  1430.80   2700.40
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11464/2277311453.py in <module>
# ----> 1 stock.interpolate(method = "time")
#
# c:\program files\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\program files\python39\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10707         **kwargs,
#   10708     ) -> DataFrame | None:
# > 10709         return super().interpolate(
#   10710             method,
#   10711             axis,
#
# ...

# %%
type(stock.DATE[0])
# Out:
# str

# %%
stock = pd.read_csv("D:\\all\\python codes\\projects\\stock price\\Final-50-stocks.csv", parse_dates =['DATE'])

# %%
type(stock.DATE[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
stock = pd.read_csv("D:\\all\\python codes\\projects\\stock price\\Final-50-stocks.csv", parse_dates =['DATE'])

# %%
stock.head()
# Out:
#         DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO   TECHM  RELIANCE  \
# 0 2010-01-11     591.90  423.70  3792.50    6737.95  735.60   1093.20
# 1 2010-01-12     613.55  414.70  3781.90    5443.70  671.15    988.80
# 2 2010-02-11     599.05  433.85  3818.70    6735.25  724.55   1074.85
# 3 2010-02-12     622.75  426.05  3784.20    5368.40  676.35   1011.15
# 4 2010-03-11     609.60  434.70  3833.05    6858.65  732.50   1065.30
#
#    SHREECEM  SUNPHARMA  TATAMOTORS  ...    BPCL  BRITANNIA  ADANIPORTS  \
# 0   2116.10    2190.70     1170.60  ...  754.80     413.15         NaN
# 1   2094.10     448.65     1286.75  ...  697.95     410.30         NaN
# 2   2164.55    2190.45     1154.25  ...  772.75     413.60         NaN
# 3   2022.35     452.90     1320.15  ...  685.80     412.45         NaN
# 4   2261.40    2249.30     1185.55  ...  765.60     415.75         NaN
#
#    BAJAJFINSERV  BAJAJFINANCE  BHARTIARTL  AXISBANK  BAJAJ-AUTO  ASIANPAINT  \
# ...

# %%
stock.interpolate(method = 'nearest')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11464/3061637133.py in <module>
# ----> 1 stock.interpolate(method = 'nearest')
#
# c:\program files\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\program files\python39\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10707         **kwargs,
#   10708     ) -> DataFrame | None:
# > 10709         return super().interpolate(
#   10710             method,
#   10711             axis,
#
# ...
